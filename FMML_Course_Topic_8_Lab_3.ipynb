# %% [markdown]
# <a href="https://colab.research.google.com/github/JuttigaGowtham/FMML-22B21A4451/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 15:22:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  80.5MB/s    in 0.9s
#
# 2024-04-03 15:22:42 (80.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11499  1603.08661v2  I introduce and analyse an anytime version of ...    cs
# 9945    1412.1138v1  A database of fetal heart rate (FHR) time seri...    cs
# 8645   1709.05672v1  We propose a new grayscale image denoiser, dub...    cs
# 2051    1406.5614v2  This paper presents eight PAC-Bayes bounds to ...    cs
# 10805   1405.3080v1  Stochastic Gradient Descent (SGD) is a popular...  stat
# ...             ...                                                ...   ...
# 27364  1703.04418v1  The main purpose of this paper is to propose a...    cs
# 22834  1708.02122v1  Very few K-nearest-neighbor (KNN) ensembles ex...  stat
# 22072   1410.0860v1  In recent years rank aggregation has received ...  stat
# 11723  1610.06525v2  Understanding how users navigate in a network ...  stat
# 6917   1707.05841v1  In this paper we propose a scalable version of...  stat
#
#                                                    title  year  \
# 11499  Regret Analysis of the Anytime Optimally Confi...  2016
# 9945        Highly comparative fetal heart rate analysis  2014
# 8645             Neural Affine Grayscale Image Denoising  2017
# 2051           PAC-Bayes Analysis of Multi-view Learning  2014
# 10805  Accelerating Minibatch Stochastic Gradient Des...  2014
# ...                                                  ...   ...
# 27364  Improving LBP and its variants using anisotrop...  2017
# 22834  KNN Ensembles for Tweedie Regression: The Powe...  2017
# 22072  Individualized Rank Aggregation using Nuclear ...  2014
# 11723  ChoiceRank: Identifying Preferences from Node ...  2016
# 6917   Linear Time Complexity Deep Fourier Scattering...  2017
#
#                                                 keywords
# 11499  [introduce, optimally, confident, algorithm, m...
# 9945   [recordings, informative, comparative, extract...
# 8645   [grayscale, denoising, typically, supervised, ...
# 2051   [generalization, performance, classifiers, dep...
# 10805  [stochastic, optimization, important, parallel...
# ...                                                  ...
# 27364  [preprocessing, descriptors, classification, p...
# 22834  [ensembles, regression, classification, detect...
# 22072  [aggregation, significant, attention, communit...
# 11723  [understanding, applications, aggregate, trans...
# 6917   [deterministic, invariant, extraction, consecu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11499    [introduce, optimally, confident, algorithm, m...
# 9945     [recordings, informative, comparative, extract...
# 8645     [grayscale, denoising, typically, supervised, ...
# 2051     [generalization, performance, classifiers, dep...
# 10805    [stochastic, optimization, important, parallel...
#                                ...
# 5997     [appropriate, architectures, regularization, s...
# 3640     [adversarial, demonstrated, fragility, imperce...
# 9687     [permutation, parametric, obtaining, distribut...
# 32233    [evolution, classification, application, techn...
# 21934    [variational, inference, approximate, probabil...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8699 words.
# Out of those 4525 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1c7a2a2c-b014-43d0-997e-05505a2d0fb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c7a2a2c-b014-43d0-997e-05505a2d0fb5")) {                    Plotly.newPlot(                        "1c7a2a2c-b014-43d0-997e-05505a2d0fb5",                        [{"x":["subgaussian","minimising","intuitive","cumulative","introduce","strongest","confident","optimally","algorithm","stochastic","guarantees","identified","contribute","developed","autocorrelation","distribution","recordings","correlation","including","biomedical","automatically","processing","scientific","comparative","challenges","extracting","available","intervention","informative","literature","successfully","collection","demonstrates","comparing","interdisciplinary","accurately","formulation","benchmark","outperform","mismatched","typically","supervised","corrected","formulate","estimated","denoising","parameters","drawbacks","grayscale","technique","generalization","important","dimensionality","classifiers","logarithmic","presented","unlabeled","discussed","dependent","applicable","determinant","performance","emphasize","represent","inequalities","agreements","usefulness","difference","calculated","accelerating","parallelize","effectiveness","minibatch","stratified","optimization","uniformly","convergence","encouraging","significantly","experimental","synthetic","estimates","simultaneously","simultaneous","reinforcement","improvements","satisfied","transition","functions","estimation","generating","approaches","additional","accessible","evaluation","originates","efficiency","describes","regarding","demonstrations","influenced","assumptions","comprehension","importance","difficult","selecting","unstructured","demonstrate","knowledge","components","information","vocabulary","consisting","structured","introduced","wikipedia","retrieval","answering","mechanism","retrieved","attention","comparison","performances","particular","procedure","computing","optimizes","architectures","considered","unsupervised","embedding","consistently","representation","statistical","structures","appropriate","increases","solutions","intermediate","segmentation","extensive","screening","segmenting","differences","differentiating","consuming","alleviate","complexity","structural","evaluated","convolutional","incredible","prevention","modalities","screenings","magnitudes","increased","automatic","utilizing","feedforward","schizophrenia","equivalent","frequentist","theoretical","conditions","existence","separability","likelihood","degeneracy","perspective","generalizing","converges","estimator","identifiability","allocation","dirichlet","underlying","dynamical","symmetric","arbitrarily","biologically","graphical","variational","encourages","plausible","corresponding","indirectly","continues","traditional","trajectory","application","trajectories","asymmetric","distributions","operators","guarantee","generated","expressing","equilibrium","stationary"],"y":[2,3,30,14,357,11,3,18,791,148,66,41,30,191,4,213,10,81,266,19,206,317,48,34,123,69,317,16,36,135,101,80,59,78,2,76,86,219,108,4,104,190,11,57,61,50,248,24,9,232,97,360,43,134,23,206,44,64,79,53,1,939,12,113,5,2,19,56,29,9,2,197,4,4,299,21,121,21,272,384,138,74,113,30,116,102,14,25,207,193,102,400,111,12,247,3,173,99,37,11,13,73,18,92,156,36,22,572,367,99,691,45,52,110,112,27,120,56,113,12,164,129,40,280,117,132,9,131,114,132,107,28,351,160,127,74,56,151,49,217,159,8,24,55,4,42,27,233,78,129,372,4,4,28,1,5,44,192,42,21,1,62,0,150,126,36,10,54,2,56,11,30,26,2,20,20,117,17,24,13,9,48,45,13,26,123,5,6,161,21,250,24,17,100,55,31,190,17,15,26],"type":"bar"},{"x":["subgaussian","minimising","intuitive","cumulative","introduce","strongest","confident", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4525,), (4525, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8216666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Limits</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5757575757575758);'>Preprocessing</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.32279909706546284);'>theoretical</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>power</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.5757575757575758);'>preprocessing</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style=''>problems</span> <span style=''>from</span> <span style=''>various</span> <span style=''>areas</span> <span style=''>in</span> <span style=''>AI</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>problems</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constraint</span> <span style='background-color:rgba(0, 255, 0, 0.8400000000000001);'>Satisfaction</span> <span style=''>Global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constraints</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>Satisfiability</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Nonmonotonic</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.8045112781954886);'>Reasoning</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>subject</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>none</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>be</span> <span style=''>reduced</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.5757575757575758);'>preprocessing</span> <span style=''>to</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>kernel</span> <span style=''>whose</span> <span style=''>size</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3069908814589666);'>parameter</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>such</span> <span style=''>as</span> <span style=''>induced</span> <span style=''>width</span> <span style=''>or</span> <span style=''>backdoor</span> <span style=''>size</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>firm</span> <span style='background-color:rgba(255, 0, 0, 0.32279909706546284);'>theoretical</span> <span style=''>boundary</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.5757575757575758);'>preprocessing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Tractable</span> <span style=''>Fully</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>via</span> <span style=''>Convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>and</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transport</span> <span style=''>Theory</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforming</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>into</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>another</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>with</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transport</span> <span style=''>theory</span> <span style=''>that</span> <span style=''>when</span> <span style=''>the</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>sampled</span> <span style=''>from</span> <span style=''>and</span> <span style=''>the</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style=''>log</span> <span style=''>concave</span> <span style=''>this</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractably</span> <span style=''>solved</span> <span style=''>with</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>this</span> <span style=''>when</span> <span style=''>the</span> <span style=''>source</span> <span style=''>is</span> <span style=''>the</span> <span style=''>prior</span> <span style=''>and</span> <span style=''>the</span> <span style=''>target</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>is</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalization</span> <span style=''>constant</span> <span style=''>and</span> <span style=''>draw</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>iid</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Remarkably</span> <span style=''>our</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>is</span> <span style=''>simply</span> <span style=''>log</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concavity</span> <span style=''>of</span> <span style=''>the</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unlabeled</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Non</span> <span style=''>Negative</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.6770186335403727);'>Estimator</span> <br/><br/><span style=''>From</span> <span style=''>only</span> <span style=''>positive</span> <span style=''>(P)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>(U)</span> <span style=''>data</span> <span style=''>a</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>could</span> <span style=''>be</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>PU</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>is</span> <span style=''>unbiased</span> <span style=''>PU</span> <span style=''>learning</span> <span style=''>However</span> <span style=''>if</span> <span style=''>its</span> <span style=''>model</span> <span style=''>is</span> <span style=''>very</span> <span style=''>flexible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risks</span> <span style=''>on</span> <span style=''>training</span> <span style=''>data</span> <span style=''>will</span> <span style=''>go</span> <span style=''>negative</span> <span style=''>and</span> <span style=''>we</span> <span style=''>will</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>serious</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.6770186335403727);'>estimator</span> <span style=''>for</span> <span style=''>PU</span> <span style=''>learning</span> <span style=''>when</span> <span style=''>getting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimized</span> <span style=''>it</span> <span style=''>is</span> <span style=''>more</span> <span style=''>robust</span> <span style=''>against</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>we</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>use</span> <span style=''>very</span> <span style=''>flexible</span> <span style=''>models</span> <span style=''>(such</span> <span style=''>as</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks)</span> <span style=''>given</span> <span style=''>limited</span> <span style=''>P</span> <span style=''>data</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>bias</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>and</span> <span style=''>mean</span> <span style=''>squared</span> <span style=''>error</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.6770186335403727);'>estimator</span> <span style=''>and</span> <span style=''>bound</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Dynamic</span> <span style=''>ECME</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>The</span> <span style=''>ECME</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerating</span> <span style=''>the</span> <span style=''>EM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>many</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recognising</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitation</span> <span style=''>of</span> <span style=''>using</span> <span style=''>prefixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acceleration</span> <span style=''>subspace</span> <span style=''>in</span> <span style=''>ECME</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>new</span> <span style=''>Dynamic</span> <span style=''>ECME</span> <span style=''>(DECME)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acceleration</span> <span style=''>subspace</span> <span style=''>to</span> <span style=''>be</span> <span style=''>chosen</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamically</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigation</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inefficient</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>DECME</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Successive</span> <span style=''>Overrelaxation</span> <span style=''>(SOR)</span> <span style=''>method</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>widely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>DECME</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>called</span> <span style=''>DECME</span> <span style=''>v1</span> <span style=''>The</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>DECME</span> <span style=''>v1</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>result</span> <span style=''>that</span> <span style=''>in</span> <span style=''>a</span> <span style=''>small</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighbourhood</span> <span style=''>of</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>estimate</span> <span style=''>(MLE)</span> <span style=''>DECME</span> <span style=''>v1</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13738819320214668)
# 	architecture (0.09159212880143112)
# 	information (0.24722719141323793)
# 	processing (0.11341681574239713)
# 	knowledge (0.13130590339892664)
# 	segmentation (0.0776386404293381)
# 	detection (0.12164579606440072)
# 	different (0.2658318425760286)
# 	convolutional (0.1330948121645796)
# 	recognition (0.13738819320214668)
#
# Some Statistics words are:
# 	stochastic (0.143142144638404)
# 	theoretical (0.14613466334164588)
# 	variables (0.142643391521197)
# 	estimation (0.16708229426433915)
# 	distribution (0.18304239401496258)
# 	statistical (0.1655860349127182)
# 	algorithm (0.3975062344139651)
# 	regression (0.17306733167082294)
# 	dimensional (0.18753117206982545)
# 	inference (0.20748129675810473)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ffb918f3-a304-451a-aa43-6a87639f22c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffb918f3-a304-451a-aa43-6a87639f22c5")) {                    Plotly.newPlot(                        "ffb918f3-a304-451a-aa43-6a87639f22c5",                        [{"x":["subgaussian","minimising","intuitive","cumulative","introduce","strongest","confident","optimally","algorithm","stochastic","guarantees","identified","contribute","developed","autocorrelation","distribution","recordings","correlation","including","biomedical","automatically","processing","scientific","comparative","challenges","extracting","available","intervention","informative","literature","successfully","collection","demonstrates","comparing","interdisciplinary","accurately","formulation","benchmark","outperform","mismatched","typically","supervised","corrected","formulate","estimated","denoising","parameters","drawbacks","grayscale","technique","generalization","important","dimensionality","classifiers","logarithmic","presented","unlabeled","discussed","dependent","applicable","determinant","performance","emphasize","represent","inequalities","agreements","usefulness","difference","calculated","accelerating","parallelize","effectiveness","minibatch","stratified","optimization","uniformly","convergence","encouraging","significantly","experimental","synthetic","estimates","simultaneously","simultaneous","reinforcement","improvements","satisfied","transition","functions","estimation","generating","approaches","additional","accessible","evaluation","originates","efficiency","describes","regarding","demonstrations","influenced","assumptions","comprehension","importance","difficult","selecting","unstructured","demonstrate","knowledge","components","information","vocabulary","consisting","structured","introduced","wikipedia","retrieval","answering","mechanism","retrieved","attention","comparison","performances","particular","procedure","computing","optimizes","architectures","considered","unsupervised","embedding","consistently","representation","statistical","structures","appropriate","increases","solutions","intermediate","segmentation","extensive","screening","segmenting","differences","differentiating","consuming","alleviate","complexity","structural","evaluated","convolutional","incredible","prevention","modalities","screenings","magnitudes","increased","automatic","utilizing","feedforward","schizophrenia","equivalent","frequentist","theoretical","conditions","existence","separability","likelihood","degeneracy","perspective","generalizing","converges","estimator","identifiability","allocation","dirichlet","underlying","dynamical","symmetric","arbitrarily","biologically","graphical","variational","encourages","plausible","corresponding","indirectly","continues","traditional","trajectory","application","trajectories","asymmetric","distributions","operators","guarantee","generated","expressing","equilibrium","stationary","principled","demonstrating","biological","soundness","recurrent","objective","restrictive","illustrating","condition","undirected","parameterized","framework","classification","correcting","decreasing","universal","extraction","overcoming","homogeneous","addressing","anatomical","neuroscience","categories","extracted","increasing","conclusions","computers","prediction","imbalance","scrambled","background","mentioned","multiclass","consonants","adaptation","thousands","challenge","preferred","assistance","deformable","sometimes","inaccuracies","performed","perception","inherently","investigate","localizing","pioneered","detection","ambiguous","different","annotated","practical","collecting","annotations","bottleneck","annotation","precision","questio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	frequentist
# 	consonants
# 	supercomputers
# 	compressibility
# 	quadrature
# 	cytometry
# 	foundational
# 	unbiasedness
# 	invariably
# 	phenotyping
# 	reparameterization
# 	misspecified
# 	certificate
# 	distributionally
# 	coincides
# 	stagewise
# 	ancestral
# 	ultrahigh
# 	marginally
# 	integrands
# Some words which never appear in Statistics papers:
# 	mismatched
# 	agreements
# 	originates
# 	incredible
# 	inaccuracies
# 	localizing
# 	rationales
# 	enforcement
# 	conjunctions
# 	quantifiers
# 	existentially
# 	authentic
# 	competitions
# 	authentication
# 	television
# 	transcriptions
# 	instagram
# 	questionnaire
# 	psychophysics
# 	humanities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079291762894534e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7825
